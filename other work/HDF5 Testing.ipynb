# %%
import pandas as pd
import numpy as np

# %%
hdf5_to_open = '/Users/Munoz/ds/aws/msd_summary_file.h5'
subset_hdf5 = '/Users/Munoz/ds/metis/million_song_sample/MillionSongSubset/AdditionalFiles/subset_msd_summary_file.h5'

file_to_use = subset_hdf5

store = pd.HDFStore(file_to_use, mode='r')
print(store)
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: /Users/Munoz/ds/metis/million_song_sample/MillionSongSubset/AdditionalFiles/subset_msd_summary_file.h5
# /analysis/songs               frame_table [0.0.0] (typ->generic,nrows->10000,ncols->31,indexers->[index],dc->[analysis_sample_rate,audio_md5,danceability,duration,end_of_fade_in,energy,idx_bars_confidence,idx_bars_start,idx_beats_confidence,idx_beats_start,idx_sections_confidence,idx_sections_start,idx_segments_confidence,idx_segments_loudness_max,idx_segments_loudness_max_time,idx_segments_loudness_start,idx_segments_pitches,idx_segments_start,idx_segments_timbre,idx_tatums_confidence,idx_tatums_start,key,key_confidence,loudness,mode,mode_confidence,start_of_fade_out,tempo,time_signature,time_signature_confidence,track_id])
# ...

# %%
group_to_analyze = '/analysis/songs'

df = store.select(group_to_analyze)

df.sample(5)
# Out:
#       analysis_sample_rate                         audio_md5  danceability  \
# 9684                 22050  674fe931e79750ee0f4156a9c8f98b8d           0.0
# 7381                 22050  b95f2b3b844b80923399c18fd224ca21           0.0
# 9158                 22050  19f0e8f4b1d1af4ffb05d7182167e072           0.0
# 6037                 22050  ab515c66e1d3d8a34ad7bd86366b11b0           0.0
# 9475                 22050  e747001b233158ba65befd545522f4a4           0.0
#
#        duration  end_of_fade_in  energy  idx_bars_confidence  idx_bars_start  \
# 9684  265.29914           0.351     0.0                    0               0
# 7381  175.15057           0.000     0.0                    0               0
# 9158  303.46404           0.067     0.0                    0               0
# 6037  246.36036           0.078     0.0                    0               0
# 9475   54.12526           0.421     0.0                    0               0
#
# ...

# %%
df[['key','tempo', 'time_signature', 'loudness', 'duration']].corr()
# Out:
#                      key     tempo  time_signature  loudness  duration
# key             1.000000  0.009821        0.003124  0.050274  0.015262
# tempo           0.009821  1.000000        0.055251  0.179354 -0.009968
# time_signature  0.003124  0.055251        1.000000  0.116122  0.111448
# loudness        0.050274  0.179354        0.116122  1.000000  0.057247
# duration        0.015262 -0.009968        0.111448  0.057247  1.000000

# %%
df.columns
# Out:
# Index(['analysis_sample_rate', 'audio_md5', 'danceability', 'duration',
#        'end_of_fade_in', 'energy', 'idx_bars_confidence', 'idx_bars_start',
#        'idx_beats_confidence', 'idx_beats_start', 'idx_sections_confidence',
#        'idx_sections_start', 'idx_segments_confidence',
#        'idx_segments_loudness_max', 'idx_segments_loudness_max_time',
#        'idx_segments_loudness_start', 'idx_segments_pitches',
#        'idx_segments_start', 'idx_segments_timbre', 'idx_tatums_confidence',
#        'idx_tatums_start', 'key', 'key_confidence', 'loudness', 'mode',
#        'mode_confidence', 'start_of_fade_out', 'tempo', 'time_signature',
#        'time_signature_confidence', 'track_id'],
#       dtype='object')

# %%
analysis_columns_to_keep = ['track_id', 'danceability', 'duration',
       'end_of_fade_in', 'energy', 'key', 'key_confidence', 'loudness', 'mode',
       'mode_confidence', 'start_of_fade_out', 'tempo', 'time_signature',
       'time_signature_confidence']

df[analysis_columns_to_keep].head(5)
# Out:
#              track_id  danceability   duration  end_of_fade_in  energy  key  \
# 0  TRACCVZ128F4291A8A           0.0  280.21506           0.238     0.0    5
# 1  TRACCMH128F428E4CD           0.0  191.68608           0.000     0.0    0
# 2  TRACCSW128F148C7C3           0.0  222.92853           0.000     0.0    1
# 3  TRACCXJ128F428F0CF           0.0  278.38649           0.496     0.0    7
# 4  TRACCVS12903D014F8           0.0   89.15546           4.847     0.0    2
#
#    key_confidence  loudness  mode  mode_confidence  start_of_fade_out  \
# 0           0.555    -3.306     1            0.500            275.528
# 1           0.501   -10.764     1            0.710            184.128
# 2           0.329    -9.035     1            0.407            216.300
# 3           0.313   -23.095     1            0.387            278.386
# 4           0.000   -20.359     1            0.000             79.203
#
#      tempo  time_signature  time_signature_confidence
# ...

# %%
df = store.select('/metadata/songs')

df.sample(5)
# Out:
#      analyzer_version  artist_7digitalid  artist_familiarity  \
# 1332                               87178            0.505269
# 1749                                2111            0.604282
# 7418                              108616            0.597538
# 1391                                 484            0.596896
# 5503                               37779            0.400296
#
#       artist_hotttnesss           artist_id  artist_latitude artist_location  \
# 1332           0.000000  ARORFIN1187FB3BE5C         43.00260  Flint Michigan
# 1749           0.407539  AR2VROU1187FB532D7         40.65507    Brooklyn, NY
# 7418           0.241317  ARIN9J01187B98BCC0              NaN
# 1391           0.365951  ARX5XTP1187FB3D8CC              NaN
# 5503           0.391342  ARUVPZF1187FB4880D              NaN       Tennessee
#
#       artist_longitude                           artist_mbid  \
# 1332         -83.78260  408f0b0a-35c9-407d-b25a-af53461dbd22
# ...

# %%
df.columns
# Out:
# Index(['analyzer_version', 'artist_7digitalid', 'artist_familiarity',
#        'artist_hotttnesss', 'artist_id', 'artist_latitude', 'artist_location',
#        'artist_longitude', 'artist_mbid', 'artist_name', 'artist_playmeid',
#        'genre', 'idx_artist_terms', 'idx_similar_artists', 'release',
#        'release_7digitalid', 'song_hotttnesss', 'song_id', 'title',
#        'track_7digitalid'],
#       dtype='object')

# %%
metadata_columns_to_keep = ['song_id', 'artist_7digitalid', 'artist_familiarity',
       'artist_hotttnesss', 'artist_id', 'artist_latitude', 'artist_location',
       'artist_longitude', 'artist_mbid', 'artist_name', 'artist_playmeid',
       'release',
       'release_7digitalid', 'song_hotttnesss', 'title',
       'track_7digitalid']

df[metadata_columns_to_keep].head(5)
# Out:
#               song_id  artist_7digitalid  artist_familiarity  \
# 0  SOVLGJY12A8C13FBED              29785            0.780462
# 1  SOGDQZK12A8C13F37C             167867            0.561590
# 2  SODMVJR12A6D4F985D               7725            0.687687
# 3  SOIWBDR12A8C13A4AC               2799            0.391741
# 4  SOHCCIA12AC907577F              74269            0.593416
#
#    artist_hotttnesss           artist_id  artist_latitude  \
# 0           0.574275  ARMQHX71187B9890D3              NaN
# 1           0.420570  AR2PT4M1187FB55B1A              NaN
# 2           0.406686  ARDI88R1187B98DAB2              NaN
# 3           0.291265  ARUKJUP12086C14589              NaN
# 4           0.395710  ARZEWUR1187FB53DC8         50.45663
#
#                                 artist_location  artist_longitude  \
# 0                                   Atlanta, GA               NaN
# 1                                                             NaN
# ...

# %%
df['genre'].describe()
# Out:
# count     10000
# unique        1
# top
# freq      10000
# Name: genre, dtype: object
